# %% [markdown]
# # EDA - Familiars

# %% [markdown]
# ## Importing Important Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## 1 . Import DataSet

# %%
df = pd.read_csv('Familiars_Clothing_Database.csv')
df
# Out:
#     Order ID  Order Date   Ship Date Customer ID   Customer Name  \
# 0    ORD1000  11-02-2024  15-02-2024     CUST456   Ajay Kulkarni
# 1    ORD1001  22-11-2023  29-11-2023     CUST282      Anil Verma
# 2    ORD1002  22-09-2023  27-09-2023     CUST420    Sakshi Patil
# 3    ORD1003  21-08-2023  24-08-2023     CUST106  Deepali Shinde
# 4    ORD1004  31-05-2023  06-06-2023     CUST804    Jyoti Mishra
# ..       ...         ...         ...         ...             ...
# 995  ORD1995  26-05-2023  29-05-2023     CUST885   Pankaj Thakur
# 996  ORD1996  12-11-2024  18-11-2024     CUST425    Kavita Joshi
# 997  ORD1997  01-11-2023  03-11-2023     CUST246     Vijay Singh
# 998  ORD1998  21-12-2024  27-12-2024     CUST453     Sachin Wagh
# 999  ORD1999  31-05-2024  03-06-2024     CUST116      Anil Verma
#
#        Customer Segment Product ID Product Name    Category Region  ...  \
# 0                locals   PROD2054     Jeggings  Kids_Girls  Rural  ...
# ...

# %% [markdown]
# ## Basic Analysis

# %% [markdown]
# ## 2. Finding Heads

# %%
df.head()
# Out:
#   Order ID Order Date  Ship Date Customer ID   Customer Name  \
# 0  ORD1000 2024-02-11 2024-02-15     CUST456   Ajay Kulkarni
# 1  ORD1001 2023-11-22 2023-11-29     CUST282      Anil Verma
# 2  ORD1002 2023-09-22 2023-09-27     CUST420    Sakshi Patil
# 3  ORD1003 2023-08-21 2023-08-24     CUST106  Deepali Shinde
# 4  ORD1004 2023-05-31 2023-06-06     CUST804    Jyoti Mishra
#
#      Customer Segment Product ID Product Name    Category Region  ...  \
# 0              locals   PROD2054     Jeggings  Kids_Girls  Rural  ...
# 1              locals   PROD5834      Tshirts   Kids_Boys  Urban  ...
# 2  Discount_Customers   PROD6665   InnerWears      Womens  Urban  ...
# 3            Tourists   PROD6259       Shorts   Kids_Boys  Rural  ...
# 4            Tourists   PROD4496      Tshirts   Kids_Boys  Urban  ...
#
#   Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 0      1865.70    1558.38   307.32           UPI         Returned
# ...

# %% [markdown]
# ## 3. Finding Tail

# %%
df.tail()
# Out:
#     Order ID Order Date  Ship Date Customer ID  Customer Name  \
# 995  ORD1995 2023-05-26 2023-05-29     CUST885  Pankaj Thakur
# 996  ORD1996 2024-11-12 2024-11-18     CUST425   Kavita Joshi
# 997  ORD1997 2023-11-01 2023-11-03     CUST246    Vijay Singh
# 998  ORD1998 2024-12-21 2024-12-27     CUST453    Sachin Wagh
# 999  ORD1999 2024-05-31 2024-06-03     CUST116     Anil Verma
#
#        Customer Segment Product ID Product Name    Category Region  ...  \
# 995  Discount_Customers   PROD2822       Shirts        Mens  Urban  ...
# 996              locals   PROD8333        Jeans   Kids_Boys  Rural  ...
# 997  Discount_Customers   PROD7284       Shirts  Kids_Girls  Rural  ...
# 998            Tourists   PROD9544      Tshirts   Kids_Boys  Rural  ...
# 999            Tourists   PROD9664       Shirts      Womens  Urban  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 995      2772.80    2389.29   383.51   Net_Banking        Delivered
# ...

# %% [markdown]
# ## 4. Finding Types

# %%
f'Data Type Is :{type(df)}'
# Out:
# "Data Type Is :<class 'pandas.DataFrame'>"

# %% [markdown]
# ## 5. Finding DataType for each Columns

# %%
df.dtypes
# Out:
# Order ID                       str
# Order Date          datetime64[us]
# Ship Date           datetime64[us]
# Customer ID                    str
# Customer Name                  str
# Customer Segment               str
# Product ID                     str
# Product Name                   str
# Category                       str
# Region                         str
# City                           str
# Village                        str
# Quanity                      int64
# Unit Price                   int64
# Discount (%)                 int64
# Sales Amount               float64
# Cost Price                 float64
# Profit                     float64
# Payment Mode                   str
# Delivery Status                str
# Supplier Name                  str
# Supplier Email                 str
# Stock_Left                   int64
# Auto Reorder                   str
# Reorder Quantity             int64
# dtype: object

# %% [markdown]
# ## 6. Finding Random Sample from Dataset

# %%
df.sample()
# Out:
#     Order ID Order Date  Ship Date Customer ID   Customer Name  \
# 384  ORD1384 2023-11-25 2023-11-27     CUST443  Rohit Deshmukh
#
#     Customer Segment Product ID Product Name Category Region  ...  \
# 384         Tourists   PROD4212        Top"s   Womens  Rural  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 384       7505.6    5532.43  1973.17          Cash         Returned
#
#                 Supplier Name                    Supplier Email  Stock_Left  \
# 384  Ganesh Garment Suppliers  ganeshgarmentsuppliers@gmail.com          17
#
#     Auto Reorder Reorder Quantity
# 384           No                0
#
# [1 rows x 25 columns]

# %% [markdown]
# ## 7. Finding Summary of Dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          1000 non-null   str
#  1   Order Date        1000 non-null   datetime64[us]
#  2   Ship Date         1000 non-null   datetime64[us]
#  3   Customer ID       1000 non-null   str
#  4   Customer Name     1000 non-null   str
#  5   Customer Segment  1000 non-null   str
#  6   Product ID        1000 non-null   str
#  7   Product Name      1000 non-null   str
#  8   Category          1000 non-null   str
#  9   Region            1000 non-null   str
#  10  City              1000 non-null   str
#  11  Village           1000 non-null   str
#  12  Quanity           1000 non-null   int64
#  13  Unit Price        1000 non-null   int64
#  14  Discount (%)      1000 non-null   int64
#  15  Sales Amount      1000 non-null   float64
#  16  Cost Price        1000 non-null   float64
# ...

# %% [markdown]
# ## 8. Finding All Columns Name

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'City', 'Village', 'Quanity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Payment Mode',
#        'Delivery Status', 'Supplier Name', 'Supplier Email', 'Stock_Left',
#        'Auto Reorder', 'Reorder Quantity'],
#       dtype='str')

# %% [markdown]
# ## 9. Finding All Data

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#     Order ID Order Date  Ship Date Customer ID      Customer Name  \
# 0    ORD1000 2024-02-11 2024-02-15     CUST456      Ajay Kulkarni
# 1    ORD1001 2023-11-22 2023-11-29     CUST282         Anil Verma
# 2    ORD1002 2023-09-22 2023-09-27     CUST420       Sakshi Patil
# 3    ORD1003 2023-08-21 2023-08-24     CUST106     Deepali Shinde
# 4    ORD1004 2023-05-31 2023-06-06     CUST804       Jyoti Mishra
# 5    ORD1005 2024-08-04 2024-08-09     CUST554     Santosh Chavan
# 6    ORD1006 2023-08-01 2023-08-04     CUST571        Neha Jadhav
# 7    ORD1007 2024-03-07 2024-03-12     CUST298        Shweta Wagh
# 8    ORD1008 2023-08-20 2023-08-22     CUST400        Shweta Wagh
# 9    ORD1009 2023-09-06 2023-09-12     CUST489        Vijay Singh
# 10   ORD1010 2024-01-10 2024-01-13     CUST193     Aarti Kulkarni
# 11   ORD1011 2024-02-04 2024-02-06     CUST916       Deepak Joshi
# 12   ORD1012 2024-01-31 2024-02-01     CUST908       Suresh Kumar
# ...

# %% [markdown]
# ## 10. Finding out the Shape of Dataset

# %%
f'there are total rows and columns are :{df.shape}'
# Out:
# 'there are total rows and columns are :(1000, 25)'

# %% [markdown]
# ## 11. Finding Description of Dataset

# %%
df.describe(include = 'object')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9720\1466716981.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include = 'object')
#        Order ID Customer ID Customer Name    Customer Segment Product ID  \
# count      1000        1000          1000                1000       1000
# unique     1000         611            40                   3        946
# top     ORD1000     CUST671  Rajesh Patil  Discount_Customers   PROD2914
# freq          1           6            35                 371          3
#
# ...

# %% [markdown]
# ## 12. Finding Null Values

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Customer ID         0
# Customer Name       0
# Customer Segment    0
# Product ID          0
# Product Name        0
# Category            0
# Region              0
# City                0
# Village             0
# Quanity             0
# Unit Price          0
# Discount (%)        0
# Sales Amount        0
# Cost Price          0
# Profit              0
# Payment Mode        0
# Delivery Status     0
# Supplier Name       0
# Supplier Email      0
# Stock_Left          0
# Auto Reorder        0
# Reorder Quantity    0
# dtype: int64

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Data Quality Check

# %%
print('\n=== DATA QUALITY ASSESSMENT ===')

# check for missing values

print('\n Missing Values: \n')
missing_data = df.isnull().sum()
print(missing_data[missing_data>0])

# check for duplicates

print(f'\n Duplicated Rows:{df.duplicated().sum()}')
# Out:
# === DATA QUALITY ASSESSMENT ===
#
#  Missing Values:
#
# Series([], dtype: int64)
#
#  Duplicated Rows:0

# %% [markdown]
# ## Data Type Conversion

# %% [markdown]
# ## Convert date column into dattime

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format='%d-%m-%y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format='%d-%m-%y')

# %% [markdown]
# ### Check Conversion

# %%
print('\n Date Columns Converted :\n')
print(f'Order Date : {df['Order Date'].dtype}')
print(f'Ship Date : {df['Ship Date'].dtype}')
# Out:
#  Date Columns Converted :
#
# Order Date : datetime64[us]
# Ship Date : datetime64[us]

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### univariate analysis is the simplest form of statistical analysis, As the name suggest uni means single/one  and variate means variable it is the analysis of single variable

# %%
print('\n=== Categorial Variables ===\n')

categorial_cols = ['Customer Segment','Category','City','Village','Payment Mode','Delivery Status','Auto Reorder']

for col in categorial_cols:
    print(f'\n-- {col} --')
    print(df[col].value_counts())
    ### Visualisation
    plt.figure(figsize=(6,6))
    df[col].value_counts().plot(kind='bar',color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# === Categorial Variables ===
#
#
# -- Customer Segment --
# Customer Segment
# Discount_Customers    371
# Tourists              329
# locals                300
# Name: count, dtype: int64
# -- Category --
# Category
# Kids_Boys     262
# Kids_Girls    250
# Womens        245
# Mens          243
# Name: count, dtype: int64
# -- City --
# City
# Chinchwad    348
# Pimpri       334
# Pune         318
# Name: count, dtype: int64
# -- Village --
# Village
# Marunji      180
# Maan         171
# Dattawadi    169
# Hinjewadi    163
# kasarsai     160
# Nere         157
# Name: count, dtype: int64
# -- Payment Mode --
# Payment Mode
# Credit_Card    285
# UPI            256
# Net_Banking    237
# Cash           222
# Name: count, dtype: int64
# -- Delivery Status --
# Delivery Status
# Pending      285
# Cancelled    254
# Returned     245
# Delivered    216
# Name: count, dtype: int64
# -- Auto Reorder --
# Auto Reorder
# No     799
# Yes    201
# Name: count, dtype: int64

# %% [markdown]
# ## Numerical Variable analysis

# %%
print('\n=== Nuerical Variables ===\n')
numerical_cols = ['Quanity','Unit Price','Discount (%)','Sales Amount','Cost Price','Profit','Stock_Left','Reorder Quantity']
for col in numerical_cols:
    print(f'\n--{col} --\n')
    print(f'Mean : {df[col].mean() :.2f}')
    print(f'Median : {df[col].median() :.2f}')
    print(f'std dev : {df[col].std() :.2f}')
    print(f'Min : {df[col].min() :.2f}')
    print(f'Max : {df[col].max() :.2f}')

# Visualisation
    plt.figure(figsize=(8,4))

    plt.subplot(1,2,1)
    df[col].hist(bins=30,color='lightgreen',alpha=0.7)
    plt.title(f'Distribution of {col}')

    plt.subplot(1,2,2)
    df.boxplot(column=col)
    plt.title(f'Boxplot of {col}')

    plt.tight_layout()
    plt.show()
# Out:
# === Nuerical Variables ===
#
#
# --Quanity --
#
# Mean : 5.45
# Median : 6.00
# std dev : 2.85
# Min : 1.00
# Max : 10.00
# --Unit Price --
#
# Mean : 2595.69
# Median : 2613.00
# std dev : 1429.72
# Min : 100.00
# Max : 4996.00
# --Discount (%) --
#
# Mean : 9.95
# Median : 10.00
# std dev : 6.94
# Min : 0.00
# Max : 20.00
# --Sales Amount --
#
# Mean : 12589.87
# Median : 9614.75
# std dev : 10241.23
# Min : 117.30
# Max : 45733.00
# --Cost Price --
#
# Mean : 9488.45
# Median : 7203.78
# std dev : 7899.00
# Min : 89.84
# Max : 37066.56
# --Profit --
#
# Mean : 3101.42
# Median : 2207.86
# std dev : 2820.09
# Min : 24.29
# Max : 14462.19
# --Stock_Left --
#
# Mean : 24.89
# Median : 25.00
# std dev : 14.62
# Min : 0.00
# Max : 50.00
# --Reorder Quantity --
#
# Mean : 7.06
# Median : 0.00
# std dev : 14.68
# Min : 0.00
# Max : 50.00

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### is the statistical anlysis of 2 variables at the same time . the core purpose is to investigate the relationship  between them

# %%
print('\n--- Sales and Profit by category ---\n')

category_performance = df.groupby('Category').agg({
    'Sales Amount' : 'sum',
    'Profit' : 'sum',
    'Order ID' : 'count'
}).rename(columns={'Order ID':'Order Count'})

category_performance['Profit Margin'] = (category_performance['Profit']/category_performance['Sales Amount'])*100
print(category_performance,'\n\n')

## Visualization

fig,axes = plt.subplots(2,2,figsize=(15,12))

## Sales by category

category_performance['Sales Amount'].plot(kind='bar',ax=axes[0,0],color='blue',alpha=0.7)
axes[0,0].set_title('Total Sales By Category')
axes[0,0].tick_params(axis='x',rotation=30)

## Profit by category

category_performance['Profit'].plot(kind='bar',ax=axes[0,1],color='green',alpha=0.7)
axes[0,1].set_title('Total Profit By Category')
axes[0,1].tick_params(axis='x',rotation=30)

## Profit Margin

category_performance['Profit Margin'].plot(kind='bar',ax=axes[1,0],color='orange',alpha=0.7)
axes[1,0].set_title('Profit Margin By Category')
axes[1,0].tick_params(axis='x',rotation=30)

## Order Count

category_performance['Order Count'].plot(kind='bar',ax=axes[1,1],color='red',alpha=0.7)
axes[1,1].set_title('Order Count By Category')
axes[1,1].tick_params(axis='x',rotation=30)

plt.tight_layout()
plt.show()
# Out:
# --- Sales and Profit by category ---
#
#             Sales Amount     Profit  Order Count  Profit Margin
# Category
# Kids_Boys     3330272.05  811547.99          262      24.368820
# Kids_Girls    3116934.10  752838.80          250      24.153183
# Mens          2921608.65  728959.30          243      24.950614
# Womens        3221052.75  808075.31          245      25.087304

# %% [markdown]
# ## Regional Performance

# %%
print('\n=== Regional Pefromance ===\n')

regional_performance = df.groupby('Region').agg({
    'Sales Amount':'sum',
    'Profit':'sum',
    'Order ID':'count'
}).rename(columns={'Order ID' : 'Order Count'})

regional_performance['Profit Margin'] = (regional_performance['Profit'] / regional_performance['Sales Amount'])*100
print(regional_performance,'\n\n')

#Visualization

plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
regional_performance['Sales Amount'].plot(kind='pie',autopct='%1.1f%%')
plt.title('Sales Distribution by Region')

plt.subplot(2,2,2)
regional_performance['Profit'].plot(kind='pie',autopct='%1.1f%%')
plt.title('Profit Distribution by Region')

plt.subplot(2,2,3)
sns.barplot(x=regional_performance.index,y='Order Count',data=regional_performance)
plt.title('Order Count by Region')
plt.xticks(rotation=30)

plt.subplot(2,2,4)
sns.barplot(x=regional_performance.index,y='Profit Margin',data=regional_performance)
plt.title('Profit Margin by Region (%)')
plt.xticks(rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === Regional Pefromance ===
#
#         Sales Amount      Profit  Order Count  Profit Margin
# Region
# Rural     7078551.35  1743695.11          540      24.633502
# Urban     5511316.20  1357726.29          460      24.635246

# %% [markdown]
# ## Category-wise Profit Analysis

# %% [markdown]
# ### Show:
#
# **Which category gives highest sales**
#
# **Which category gives lowest profit**
#
# **Which category has poor profit margin**

# %%
category_performance
# Out:
#             Sales Amount     Profit  Order Count  Profit Margin
# Category
# Kids_Boys     3330272.05  811547.99          262      24.368820
# Kids_Girls    3116934.10  752838.80          250      24.153183
# Mens          2921608.65  728959.30          243      24.950614
# Womens        3221052.75  808075.31          245      25.087304

# %% [markdown]
# ## Region-wise Profit Analysis

# %%
regional_performance
# Out:
#         Sales Amount      Profit  Order Count  Profit Margin
# Region
# Rural     7078551.35  1743695.11          540      24.633502
# Urban     5511316.20  1357726.29          460      24.635246

# %% [markdown]
# ## Product-Level Dead Stock Analysis

# %%
df.groupby('Product Name')

# %%
product_performance = df.groupby('Product Name').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

product_performance['Profit Margin'] = (
    product_performance['Profit'] / product_performance['Sales Amount']
) * 100

print(product_performance.sort_values(
    by='Sales Amount',
    ascending=False
).head(20))
# Out:
#               Sales Amount     Profit  Order Count  Profit Margin
# Product Name
# Shirts          2294913.60  547178.87          174      23.843114
# Jeans           2270677.65  579056.33          173      25.501477
# Jackets         1357818.55  331043.46          128      24.380537
# Jeggings        1138132.80  277506.68           84      24.382627
# Innerwears      1130468.75  280562.16           93      24.818215
# InnerWears       731285.65  174457.41           51      23.856261
# Tshirts          576638.35  152156.13           43      26.386752
# innerwears       561787.65  143831.45           35      25.602459
# Top"s            485187.15  127928.96           33      26.366931
# Trousers         457753.25  107678.91           46      23.523352
# Shorts           457280.70   99541.74           39      21.768192
# T-shirts         401012.85  104316.71           36      26.013309
# Tops             399294.90   87864.98           33      22.005034
# ...

# %% [markdown]
# ## Find Lowest Performing Products

# %%
print(product_performance.sort_values(
    by='Sales Amount',
    ascending=True
).head(20))
# Out:
#               Sales Amount     Profit  Order Count  Profit Margin
# Product Name
# Skirts           327615.70   88297.61           32      26.951581
# Tops             399294.90   87864.98           33      22.005034
# T-shirts         401012.85  104316.71           36      26.013309
# Shorts           457280.70   99541.74           39      21.768192
# Trousers         457753.25  107678.91           46      23.523352
# Top"s            485187.15  127928.96           33      26.366931
# innerwears       561787.65  143831.45           35      25.602459
# Tshirts          576638.35  152156.13           43      26.386752
# InnerWears       731285.65  174457.41           51      23.856261
# Innerwears      1130468.75  280562.16           93      24.818215
# Jeggings        1138132.80  277506.68           84      24.382627
# Jackets         1357818.55  331043.46          128      24.380537
# Jeans           2270677.65  579056.33          173      25.501477
# ...

# %% [markdown]
# ## Bottom 10 Products by Sales

# %%
bottom_products = product_performance.sort_values(
    by='Sales Amount'
).head(10)

plt.figure(figsize=(12,6))

bottom_products['Sales Amount'].plot(
    kind='bar',
    color='red'
)

plt.title('Bottom 10 Low-Selling Products')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation

# %% [markdown]
# **1. Shorts = Low Sales + Lowest Margin → Weak Product**
#
# **2. Tops = Low Sales + Low Margin → Dead Stock Risk**
#
# **3. Skirts = Low Sales but Good Margin → Improve Marketing Instead**
#
# **4. Jeans = High Sales + High Profit → Hero Product**
#
# **5. Shirts = Highest Sales but Lower Margin → Margin Leakage**
#
# **6. Innerwears = Stable High Performer**

# %% [markdown]
# ## Decision

# %% [markdown]
# **1. Reduce purchase volume of Shorts and renegotiate supplier pricing.**
#
# **2. Lower reorder frequency for Tops and prioritize better-performing alternatives.**
#
# **3. Promote Skirts through targeted campaigns instead of reducing stock.**
#
# **4. Increase stock availability and marketing investment for Jeans**
#
# **5. Improve vendor negotiation and pricing strategy for Shirts to protect margins.**
#
# **6. Maintain optimized stock levels and support repeat purchase strategy.**

# %% [markdown]
# ## Customer Segment Analysis

# %%
df.groupby('Customer Segment')

# %%
print('\n=== Customer Segment Analysis ===\n')

customer_segment = df.groupby('Customer Segment').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

customer_segment['Profit Margin'] = (
    customer_segment['Profit'] / customer_segment['Sales Amount']
) * 100

print(customer_segment)
# Out:
# === Customer Segment Analysis ===
#
#                     Sales Amount      Profit  Order Count  Profit Margin
# Customer Segment
# Discount_Customers    4881503.25  1233600.36          371      25.270911
# Tourists              3874580.90   950707.31          329      24.537036
# locals                3833783.40   917113.73          300      23.921897

# %% [markdown]
# ## Business Insight
# **Repeat customers = strongest revenue source**
#
# **High-value customers = marketing priority**

# %% [markdown]
# ## Payment Mode Analysis

# %%
print('\n=== Payment Mode Analysis ===\n')

payment_analysis = df.groupby('Payment Mode').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

payment_analysis['Profit Margin'] = (
    payment_analysis['Profit'] / payment_analysis['Sales Amount']
) * 100

print(payment_analysis)
# Out:
# === Payment Mode Analysis ===
#
#               Sales Amount     Profit  Order Count  Profit Margin
# Payment Mode
# Cash            2651963.35  685438.60          222      25.846458
# Credit_Card     3553120.65  884813.69          285      24.902439
# Net_Banking     3217309.95  793588.89          237      24.666224
# UPI             3167473.60  737580.22          256      23.286073

# %% [markdown]
# ## Business Insight
# **UPI / Online often drive better conversion**
#
# **Supports digital-first campaigns**

# %% [markdown]
# ## Delivery Status Analysis

# %%
print('\n=== Delivery Status Analysis ===\n')

delivery_analysis = df.groupby('Delivery Status').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

delivery_analysis['Profit Margin'] = (
    delivery_analysis['Profit'] / delivery_analysis['Sales Amount']
) * 100

print(delivery_analysis)
# Out:
# === Delivery Status Analysis ===
#
#                  Sales Amount     Profit  Order Count  Profit Margin
# Delivery Status
# Cancelled          3327917.05  823400.17          254      24.742208
# Delivered          2972335.35  725923.10          216      24.422651
# Pending            3409351.95  849237.46          285      24.909058
# Returned           2880263.20  702860.67          245      24.402654

# %% [markdown]
# ## Business Insight
#
# **Delayed deliveries reduce repeat purchases**
#
# **Failed deliveries create revenue leakage**

# %% [markdown]
# ## Monthly Sales Trend Analysis

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Month'] = df['Order Date'].dt.month_name()

monthly_sales = df.groupby('Month').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum'
})

print('\n=== Monthly Sales Trend ===\n')
print(monthly_sales)
# Out:
# === Monthly Sales Trend ===
#
#            Sales Amount     Profit
# Month
# April         761594.30  194001.57
# August       1647441.20  382817.57
# December     1279424.60  323199.85
# February      713931.95  158454.37
# January       758890.10  200267.10
# July          911021.10  234217.75
# June         1205911.75  297387.47
# March         682736.85  167653.56
# May          1040469.85  259681.57
# November     1271437.80  322045.98
# October      1290240.55  307331.45
# September    1026767.50  254363.16

# %% [markdown]
# ## Better Month Order

# %%
month_order = [
    'January', 'February', 'March', 'April',
    'May', 'June', 'July', 'August',
    'September', 'October', 'November', 'December'
]

monthly_sales = monthly_sales.reindex(month_order)
print(monthly_sales)
# Out:
#            Sales Amount     Profit
# Month
# January       758890.10  200267.10
# February      713931.95  158454.37
# March         682736.85  167653.56
# April         761594.30  194001.57
# May          1040469.85  259681.57
# June         1205911.75  297387.47
# July          911021.10  234217.75
# August       1647441.20  382817.57
# September    1026767.50  254363.16
# October      1290240.55  307331.45
# November     1271437.80  322045.98
# December     1279424.60  323199.85

# %% [markdown]
# ## Business Insight
# **Festival months = sales spike**
#
# **Low months = opportunity for campaigns**

# %% [markdown]
# ## Auto Reorder / Repeat Purchase Analysis

# %%
print('\n=== Auto Reorder Analysis ===\n')

reorder_analysis = df.groupby('Auto Reorder').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

reorder_analysis['Profit Margin'] = (
    reorder_analysis['Profit'] / reorder_analysis['Sales Amount']
) * 100

print(reorder_analysis)
# Out:
# === Auto Reorder Analysis ===
#
#               Sales Amount      Profit  Order Count  Profit Margin
# Auto Reorder
# No             10188812.85  2524668.77          799      24.778832
# Yes             2401054.70   576752.63          201      24.020803

# %% [markdown]
# ## Business Insight
# **Auto reorder customers = loyal customers**
#
# **Higher LTV (Lifetime Value)**
#
# **Best target for retention campaigns**

# %% [markdown]
# ## Time Series Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert date column
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Create Year-Month column
df['YearMonth'] = df['Order Date'].dt.to_period('M')

# Monthly sales summary
monthly_trend = df.groupby('YearMonth').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

print('\n=== Monthly Sales Trend ===\n')
print(monthly_trend)
# Out:
# === Monthly Sales Trend ===
#
#            Sales Amount     Profit  Order Count
# YearMonth
# 2023-05       443449.35  105913.32           40
# 2023-06       471632.10  107951.30           42
# 2023-07       427183.00  116846.27           40
# 2023-08       678223.30  144010.07           58
# 2023-09       568545.30  138932.86           52
# 2023-10       672433.40  165007.59           55
# 2023-11       557762.45  141612.42           49
# 2023-12       707681.00  186449.84           47
# 2024-01       758890.10  200267.10           55
# 2024-02       713931.95  158454.37           47
# 2024-03       682736.85  167653.56           53
# 2024-04       761594.30  194001.57           58
# 2024-05       597020.50  153768.25           51
# 2024-06       734279.65  189436.17           49
# 2024-07       483838.10  117371.48           49
# 2024-08       969217.90  238807.50           62
# 2024-09       458222.20  115430.30           41
# 2024-10       617807.15  142323.86           50
# ...

# %% [markdown]
# ## Line Chart Visualization of above

# %% [markdown]
# ### To Identify:
#
# **peak months**
#
# **weak months**
#
# **sudden drops**
#
# **growth trend**

# %%
plt.figure(figsize=(14,6))

monthly_trend['Sales Amount'].plot(
    kind='line',
    marker='o'
)

plt.title('Monthly Sales Trend')
plt.ylabel('Sales Amount')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Monthly Profit Trend

# %%
plt.figure(figsize=(14,6))

monthly_trend['Profit'].plot(
    kind='line',
    marker='o'
)

plt.title('Monthly Profit Trend')
plt.ylabel('Profit')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Profit Margin Trend

# %%
monthly_trend['Profit Margin'] = (
    monthly_trend['Profit'] /
    monthly_trend['Sales Amount']
) * 100

plt.figure(figsize=(14,6))

monthly_trend['Profit Margin'].plot(
    kind='line',
    marker='o'
)

plt.title('Monthly Profit Margin Trend')
plt.ylabel('Profit Margin %')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Year-over-Year (YoY) Growth

# %%
df['Year'] = df['Order Date'].dt.year

yearly_sales = df.groupby('Year').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum'
})

print('\n=== Yearly Sales Performance ===\n')
print(yearly_sales)
# Out:
# === Yearly Sales Performance ===
#
#       Sales Amount      Profit
# Year
# 2023    4526909.90  1106723.67
# 2024    8062957.65  1994697.73

# %% [markdown]
# ### I performed time series analysis to identify seasonal demand spikes and low-performing months.
# ### Based on this, I aligned digital campaigns with peak buying periods,
# ### optimized stock planning, and improved customer targeting, resulting in stronger annual sales growth.

# %% [markdown]
# ## Correlation Heatmap Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr_matrix = numeric_df.corr()

print('\n=== Correlation Matrix ===\n')
print(corr_matrix)

# Heatmap
plt.figure(figsize=(12,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
# === Correlation Matrix ===
#
#                    Quanity  Unit Price  Discount (%)  Sales Amount  \
# Quanity           1.000000   -0.047154     -0.016962      0.617366
# Unit Price       -0.047154    1.000000     -0.023110      0.655975
# Discount (%)     -0.016962   -0.023110      1.000000     -0.123192
# Sales Amount      0.617366    0.655975     -0.123192      1.000000
# Cost Price        0.604529    0.645888     -0.119347      0.984753
# Profit            0.548710    0.573073     -0.113088      0.873259
# Stock_Left        0.020475   -0.021615      0.028990      0.003002
# Reorder Quantity -0.008215   -0.029003     -0.018343     -0.025080
#
#                   Cost Price    Profit  Stock_Left  Reorder Quantity
# Quanity             0.604529  0.548710    0.020475         -0.008215
# Unit Price          0.645888  0.573073   -0.021615         -0.029003
# Discount (%)       -0.119347 -0.113088    0.028990         -0.018343
# ...

# %% [markdown]
# ## Correlation analysis revealed that excessive discounting negatively impacted profitability,
# ## while high-volume product categories significantly improved revenue contribution.
# ## This supported smarter pricing and inventory decisions
